# %%
#After importing the dataset using Pandas start by showing the head of the dataset then some general information about the data columns and values

import pandas as pd
data=pd.read_csv('titanic-passengers.csv', sep=";")
#J’utilise Colac on ligne pour écrire le code donc c’est pour cela que le chemin d’axés au fichier CSV est uniquement son nom entre ‘’
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#Some general information about the data columns and values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
#next step apply what you have learned in the course to preprocess your data
data.isnull()
#identify missing values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.isnull().sum()
# inventory of missing values by columns
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.isnull().sum().sum()
#sum of missing values
# Out:
# 866

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.describe(include="all")
#Descriptive statistics
# Out:
#         PassengerId Survived      Pclass               Name   Sex         Age  \
# count    891.000000      891  891.000000                891   891  714.000000
# unique          NaN        2         NaN                891     2         NaN
# top             NaN       No         NaN  Davis, Miss. Mary  male         NaN
# freq            NaN      549         NaN                  1   577         NaN
# mean     446.000000      NaN    2.308642                NaN   NaN   29.699118
# std      257.353842      NaN    0.836071                NaN   NaN   14.526497
# min        1.000000      NaN    1.000000                NaN   NaN    0.420000
# 25%      223.500000      NaN    2.000000                NaN   NaN   20.125000
# 50%      446.000000      NaN    3.000000                NaN   NaN   28.000000
# 75%      668.500000      NaN    3.000000                NaN   NaN   38.000000
# max      891.000000      NaN    3.000000                NaN   NaN   80.000000
#
# ...

# %%
# First let's eliminate the lines which are completely empty with the DROPNA function if they exist
import numpy as np
import pandas as pd
data=pd.read_csv('titanic-passengers.csv', sep=";")
data.dropna(axis=1, how='all', thresh=None,inplace= False)
data.isnull().sum().sum()
# Out:
# 866

# %%
#Replace empty age values with mode
import numpy as np
import pandas as pd
data['Age'].fillna(data['Age'].mode(), inplace=True)
data.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# ...

# %%
#Identify the most used cabins
nb=len(data['Cabin'])
print(nb)
print(data["Cabin"].value_counts())
# Out:
# 891
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# C22 C26        3
#               ..
# A20            1
# C70            1
# C118           1
# D47            1
# A14            1
# Name: Cabin, Length: 147, dtype: int64

# %%
# Let's replace the voids with the most used cabin
data['Cabin'].fillna('G6', inplace=True)
data.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# ...

# %%
#3. Let’s begin now the data visualization part : 
#Start by studying the distribution of the most important features based on your understanding of the dataset and the problem

import matplotlib.pyplot as plt

plt.title("histogram")
plt.xlabel("Age")
data['Age'].plot.hist()
# Age With matplotlib

# %%
# Age with seaborn

import seaborn as sns
sns.distplot(data['Age'], bins=10, hist=True, kde=True, color="red")

# %%
import matplotlib.pyplot as plt

plt.xlabel("Pclass")
plt.ylabel("Pclass value cont")
plt.title("barplot")
vc=data['Pclass'].value_counts()
vc.plot.bar(rot=0)

# Pclass With matplotlib

# %%
# Age with seaborn

import seaborn as sns

sns.countplot(x='Pclass',data=data)
plt.xticks(rotation=1)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
import matplotlib.pyplot as plt

plt.xlabel("Sex")
plt.ylabel("Sex value cont")
plt.title("barplot")
vc=data['Sex'].value_counts()
vc.plot.bar(rot=0)

# Sex with matplotlib

# %%
import seaborn as sns

sns.countplot(x='Sex',data=data)
plt.xticks(rotation=1)

#Sex with Seaborn
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
#Plotbox from  matplotlib

import matplotlib as plt
data["Age"].plot.box()

# %%
#boxplot with Seaborn

import seaborn as sns
DATA= data.drop(["Age","Pclass"],axis = 1)
sns.boxplot(data["Age"], width=0.5)

# %%
# Visualize Pclass and Age in boxplot on the same graph

## leave only Pclass and Age

data1=data.drop(["PassengerId","Name","SibSp","Parch","Ticket","Fare","Cabin","Embarked"],axis=1)
data1.head()
# Out:
#   Survived  Pclass     Sex   Age
# 0       No       2    male  28.0
# 1       No       3    male  25.0
# 2       No       3    male  20.0
# 3       No       3  female  29.0
# 4       No       1    male  31.0

# %%
# Visualize Pclass and Age in boxplot on the same graph
sns.boxplot(data=data1)

# %%
#Standardization of values for correct visualization

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data1["Age"]=scaler.fit_transform(data1[["Age"]].values)
data1["Pclass"]=scaler.fit_transform(data1[["Pclass"]].values)

sns.boxplot(data=data1)

# %%
#We will deduce a correlation between catgorical Value and a numerical Value so we will superimpose their Histogram using Seaborn: Sex vs Survived

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(data, col='Survived')
g.map(plt.hist, "Sex");
print("Female individuals more likely to survive than die and Male individuals more likely to die than survive")



g = sns.FacetGrid(data, col='Sex')
g.map(plt.hist, "Survived")
# Out:
# Female individuals more likely to survive than die and Male individuals more likely to die than survive

# %%
# Age vs Survived

g = sns.FacetGrid(data, col='Survived')
g.map(plt.hist, "Age");

print("People between the ages of 15 and 50 are more likely to survive than die. Others are more likely to die than to survive.")
# Out:
# People between the ages of 15 and 50 are more likely to survive than die. Others are more likely to die than to survive.

# %%
# Sex and Age vs Survived

g = sns.FacetGrid(data, hue='Sex', col='Age',)
g.map(plt.hist, "Survived")

g=sns.FacetGrid(data,col='Survived')
g.map(sns.barplot,'Age', 'Sex')
# Out:
# c:\python3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Sex and Age vs Survived

g = sns.FacetGrid(data,hue='Sex',col='Survived')
g.map(plt.hist, 'Age',bins=10);
g.add_legend();
print("Whatever their age, a female individual has a greater chance of survival than a male individual")
# Out:
# Whatever their age, a female individual has a greater chance of survival than a male individual

# %%
# Sex and Age vs Survived

g = sns.FacetGrid(data,hue='Survived',col='Sex')
g.map(plt.hist, 'Age',bins=10);
g.add_legend();
print("Male individuals under the age of 10 and +75 are more likely to die than survive. and the reverse is true for other ages")
print("Whatever their age, a female individual is more likely to survive than to die. Except for an age between 8 and 16 years old.")
# Out:
# Male individuals under the age of 10 and +75 are more likely to die than survive. and the reverse is true for other ages
# Whatever their age, a female individual is more likely to survive than to die. Except for an age between 8 and 16 years old.

# %%
# Question:Try running the function, analyse what does it do exactly and what are the utilities of it, write a pragraph describing your analysis (the paragraph should be in english)

corr = data.corr()
# calcule la correlation
s , ax = plt.subplots( figsize =( 12 , 10 ) )
#plt.subplots Creating multiple subplots
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#Make a diverging palette between two HUSL colors
s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })
# Plot rectangular data as a color-encoded matrix  

print(s)
# "As a reminder
# corr <0.5: No correlation.
# 0.5 <corr <0.7: a correlation is possible, more analysis is needed.
# 0.7 <corr: there is a correlation.
#
# My conclusions are:

# 1) A possible correlation between Fare and Pclass
# 2) No correlation is evident elsewhere")
# Out:
# AxesSubplot(0.125,0.1305;0.62x0.744)

# %%
# Use the groupby function combined with the mean() to view the relation between pclass and survived 
data[['Age','Survived']].groupby(['Survived'],as_index=True).mean()
# Out:
#                 Age
# Survived
# No        30.626179
# Yes       28.343690

# %%
#As a final step try to drop the useless columns such as Names:
new_data=data.drop(['Name'], axis=1)
new_data.head(3)
# Out:
#    PassengerId Survived  Pclass   Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0          343       No       2  male  28.0      0      0  248740  13.0000
# 1           76       No       3  male  25.0      0      0  348123   7.6500
# 2          641       No       3  male  20.0      0      0  350050   7.8542
#
#    Cabin Embarked
# 0     G6        S
# 1  F G73        S
# 2     G6        S

# %%
data.head(3)
# Out:
#    PassengerId Survived  Pclass                        Name   Sex   Age  \
# 0          343       No       2  Collander, Mr. Erik Gustaf  male  28.0
# 1           76       No       3     Moen, Mr. Sigurd Hansen  male  25.0
# 2          641       No       3      Jensen, Mr. Hans Peder  male  20.0
#
#    SibSp  Parch  Ticket     Fare  Cabin Embarked
# 0      0      0  248740  13.0000     G6        S
# 1      0      0  348123   7.6500  F G73        S
# 2      0      0  350050   7.8542     G6        S

# %%
#your task now is to create a new column called Title which contain the appropriate Title for each individual ( hint : extract the title from the column Names)

import numpy as np
import pandas as pd

new_data2 = data.copy()

df=pd.DataFrame({'Name': new_data2['Name']})

# Spliter avec la virgule:
new_data2['Last name'], new_data2['First name'] = new_data2['Name'].str.split(',', 1).str
# Spliter avec le point:
new_data2['Title'], new_data2[' First name'] = new_data2['First name'].str.split('.', 1).str

new_data2.head(3)
# Out:
# <ipython-input-35-ae8363d372ba>:11: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   new_data2['Last name'], new_data2['First name'] = new_data2['Name'].str.split(',', 1).str
# <ipython-input-35-ae8363d372ba>:13: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   new_data2['Title'], new_data2[' First name'] = new_data2['First name'].str.split('.', 1).str
#    PassengerId Survived  Pclass                        Name   Sex   Age  \
# 0          343       No       2  Collander, Mr. Erik Gustaf  male  28.0
# 1           76       No       3     Moen, Mr. Sigurd Hansen  male  25.0
# 2          641       No       3      Jensen, Mr. Hans Peder  male  20.0
#
#    SibSp  Parch  Ticket     Fare  Cabin Embarked  Last name  \
# 0      0      0  248740  13.0000     G6        S  Collander
# 1      0      0  348123   7.6500  F G73        S       Moen
# 2      0      0  350050   7.8542     G6        S     Jensen
#
# ...

# %%
#Visualise the correlation between Title and other features(e.g Sex, Fare, Age...)

# %%
# to_numeric for Survived Column

new_data3 = new_data2.copy()

Survived_to_numerical = { "Survived": {"No": 0, "Yes": 1}}

new_data3.replace(Survived_to_numerical, inplace=True)


new_data3.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  Last name  \
# 0    male  28.0      0      0      248740  13.0000     G6        S  Collander
# 1    male  25.0      0      0      348123   7.6500  F G73        S       Moen
# 2    male  20.0      0      0      350050   7.8542     G6        S     Jensen
# 3  female  29.0      0      4      349909  21.0750     G6        S    Palsson
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S   Davidson
#
# ...

# %%
# to_numeric for Sex Column 

new_data4 = new_data3.copy()

sex_to_numerical={ "Sex": {"male": 0, "female": 1}}

new_data4.replace(sex_to_numerical, inplace=True)

new_data4.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  Last name  \
# 0    0  28.0      0      0      248740  13.0000     G6        S  Collander
# 1    0  25.0      0      0      348123   7.6500  F G73        S       Moen
# 2    0  20.0      0      0      350050   7.8542     G6        S     Jensen
# 3    1  29.0      0      4      349909  21.0750     G6        S    Palsson
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S   Davidson
#
# ...

# %%
# to_numeric for Title Column 
from sklearn.preprocessing import LabelEncoder

new_data5 = new_data4.copy()

encoder=LabelEncoder()
new_data5['Title']=encoder.fit_transform(new_data5['Title'])
new_data5.head()

new_data5['Title'].unique()
# Out:
# array([11, 12,  8,  3,  6,  2,  7, 14,  1,  9,  5,  4, 10, 15,  0, 16, 13])

# %%
#les't verfy
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
#Visualise the correlation between Title and other features(e.g Sex, Fare, Age...) 
    
corr = new_data5.corr()
# calcule la correlation
s , ax = plt.subplots( figsize =( 12 , 10 ) )
#plt.subplots Creating multiple subplots
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#Make a diverging palette between two HUSL colors
s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })
# Plot rectangular data as a color-encoded matrix  
new_data5.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  Last name  \
# 0    0  28.0      0      0      248740  13.0000     G6        S  Collander
# 1    0  25.0      0      0      348123   7.6500  F G73        S       Moen
# 2    0  20.0      0      0      350050   7.8542     G6        S     Jensen
# 3    1  29.0      0      4      349909  21.0750     G6        S    Palsson
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S   Davidson
#
# ...

# %%
#No obvious correlation between title and other columns

# %%
# use the Title dictionary
Title_Dictionary={}
Title_Dictionary = Title_Dictionary = { "Capt":"Officer","Col":        "Officer","Major":      "Officer", "Dr":         "Officer","Rev": "Officer", "Jonkheer":   "Royalty",  "Don":        "Royalty",  "Sir" :       "Royalty", "Lady" :      "Royalty", "Mme":        "Miss",   "Mlle":       "Miss",  "Miss" :      "Miss","Ms":         "Mrs", "Mr" :        "Mrs",   "Master" :    "Master" }

Title_Dictionary.update( {   'the Countess': "Royalty"})
Title_Dictionary.update( {    "Dona"    :  "Royalty",})
Title_Dictionary.update({"Mrs" :       "Mrs",})

Title_Dictionary
# Out:
# {'Capt': 'Officer',
#  'Col': 'Officer',
#  'Major': 'Officer',
#  'Dr': 'Officer',
#  'Rev': 'Officer',
#  'Jonkheer': 'Royalty',
#  'Don': 'Royalty',
#  'Sir': 'Royalty',
#  'Lady': 'Royalty',
#  'Mme': 'Miss',
#  'Mlle': 'Miss',
#  'Miss': 'Miss',
#  'Ms': 'Mrs',
#  'Mr': 'Mrs',
#  'Master': 'Master',
#  'the Countess': 'Royalty',
#  'Dona': 'Royalty',
#  'Mrs': 'Mrs'}

# %%
#hint: use the following dictionary
new_data6 = new_data4.copy()

new_data4.replace(Title_Dictionary, inplace=True)

new_data4["Title"].unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Dr', ' Major', ' Don', ' Master', ' Rev',
#        ' Col', ' Mlle', ' Lady', ' Jonkheer', ' Mme', ' Sir', ' Capt',
#        ' the Countess', ' Ms'], dtype=object)

# %%
New_titles_numeric  = {'Capt': 0,
 'Col': 0,
 'Major': 0,
 'Dr': 0,
 'Rev': 0,
 'Jonkheer': 1,
 'Don': 1,
 'Sir': 1,
 'Lady': 1,
 'Mme': 3,
 'Mlle': 3,
 'Miss': 3,
 'Ms': 4,
 'Mr': 4,
 'Master': 5,
 'the Countess': 2,
 'Dona': 2,
 'Mrs': 4}

# %%
new_data6 = new_data4.copy()

new_data6.replace (New_titles_numeric, inplace=True)

new_data6["Title"].unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Dr', ' Major', ' Don', ' Master', ' Rev',
#        ' Col', ' Mlle', ' Lady', ' Jonkheer', ' Mme', ' Sir', ' Capt',
#        ' the Countess', ' Ms'], dtype=object)

# %%
corr = new_data6.corr()
# calcule la correlation
s , ax = plt.subplots( figsize =( 12 , 10 ) )
#plt.subplots Creating multiple subplots
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#Make a diverging palette between two HUSL colors
s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })
# Plot rectangular data as a color-encoded matrix  
new_data6.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  Last name  \
# 0    0  28.0      0      0      248740  13.0000     G6        S  Collander
# 1    0  25.0      0      0      348123   7.6500  F G73        S       Moen
# 2    0  20.0      0      0      350050   7.8542     G6        S     Jensen
# 3    1  29.0      0      4      349909  21.0750     G6        S    Palsson
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S   Davidson
#
# ...

# %%
#Finally, use the Parch and the SibSp columns to create a more useful feature, let's call it FamilySize.
FamilySize = ["Parch","SibSp"]
new_data6['FamilySize'] = new_data6[FamilySize].sum(axis=1)
new_data6.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                         Collander, Mr. Erik Gustaf    0  28.0      0      0
# 1                            Moen, Mr. Sigurd Hansen    0  25.0      0      0
# 2                             Jensen, Mr. Hans Peder    0  20.0      0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)    1  29.0      0      4
# 4                             Davidson, Mr. Thornton    0  31.0      1      0
# 5                     Gustafsson, Mr. Anders Vilhelm    0  37.0      2      0
# ...

# %%
corr = new_data6.corr()
# calcule la correlation
s , ax = plt.subplots( figsize =( 12 , 10 ) )
#plt.subplots Creating multiple subplots
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#Make a diverging palette between two HUSL colors
s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })
# Plot rectangular data as a color-encoded matrix  
new_data6.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked  Last name  \
# 0    0  28.0      0      0      248740  13.0000     G6        S  Collander
# 1    0  25.0      0      0      348123   7.6500  F G73        S       Moen
# 2    0  20.0      0      0      350050   7.8542     G6        S     Jensen
# 3    1  29.0      0      4      349909  21.0750     G6        S    Palsson
# 4    0  31.0      1      0  F.C. 12750  52.0000    B71        S   Davidson
#
# ...

# %%
#no obvious correlation

# %%
# Use the groupby function combined with the mean() to view the relation 
new_data6[['FamilySize','Survived']].groupby(['Survived'],as_index=True).mean()
# Out:
#           FamilySize
# Survived
# 0           0.883424
# 1           0.938596

# %%
# Use the groupby function combined with the mean() to view the relation 
new_data6[['FamilySize','Survived']].groupby(['FamilySize'],as_index=True).mean()
# Out:
#             Survived
# FamilySize
# 0           0.303538
# 1           0.552795
# 2           0.578431
# 3           0.724138
# 4           0.200000
# 5           0.136364
# 6           0.333333
# 7           0.000000
# 10          0.000000

# %%
# those who survived the most have families with 1 to 3 members!!

# Merci Iheb!!
