# %% [markdown]
# 1. Explore this dataset using what you have learned in data preprocessing and data visualization

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
#import the CSV datset
data=pd.read_csv('kc_house_data.csv', sep=",")
data.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
data.info(3)
print("Our features are numerical")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.isnull().sum().sum()

print("no Nan, data is clean")
# Out:
# no Nan, data is clean

# %%
#Visualise the correlation between price and other features
import seaborn as sns    
corr = data.corr()
# calcule la correlation
s , ax = plt.subplots( figsize =( 20 , 20 ) )
#plt.subplots Creating multiple subplots
cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#Make a diverging palette between two HUSL colors
s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })
# Plot rectangular data as a color-encoded matrix

# %% [markdown]
# exercice 2) Write a paragraph selecting the most important features (feature selection).

# %% [markdown]
# by observing the correlation matrix between the different items:
#
# And among these items, we have chosen those that have a correlation index above 0.5. therefore they present a possible correlation with the price. These items are as follows:
#
# # bathrooms
# # sqft_living
# # grade
# # sqft_above
# # sqft_living15

# %% [markdown]
# Exercice 3) Split your dataset into a training set and a testing set.
# Exercice 4) Apply Linear regression to your training set.
# Exercice 5) Plot the linear regression.
# Exercice 6) Measure the performance of linear regression using the testing set.

# %%
#Split the dataset, Train test aned Linear regression for the feature: yr_built

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x=data['yr_built'].values[:,np.newaxis]
y=data['price'].values
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=30)

model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 124572844127.76807
# R squared 0.006171186636215409

# %%
# Plot the linear regression. 'yr_built'

plt.scatter(x,y,color='r')
plt.title('Linear Regression')
plt.ylabel('price')
plt.xlabel('yr_built')
plt.plot(x,model.predict(x), color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Split the dataset, Train test aned Linear regression for the feature: bathrooms
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x=data['bathrooms'].values[:,np.newaxis]
y=data['price'].values
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=30)

model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 91352317950.32462
# R squared 0.27120098780529545

# %%
# Plot the linear regression. 'bathrooms'

plt.scatter(x,y,color='r')
plt.title('Linear Regression')
plt.ylabel('price')
plt.xlabel('bathrooms')
plt.plot(x,model.predict(x), color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Split the dataset, Train test aned Linear regression for the feature:sqft_living
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x=data['sqft_living'].values[:,np.newaxis]
y=data['price'].values
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=30)

model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 64179676631.68388
# R squared 0.4879814110728805

# %%
# Plot the linear regression. 'sqft_living'

plt.scatter(x,y,color='r')
plt.title('Linear Regression')
plt.ylabel('price')
plt.xlabel('sqft_living')
plt.plot(x,model.predict(x), color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Split the dataset, Train test aned Linear regression for the feature:grade
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x=data['grade'].values[:,np.newaxis]
y=data['price'].values
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=30)

model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 66520040908.336136
# R squared 0.46931023543913863

# %%
# Plot the linear regression. 'grade'

plt.scatter(x,y,color='r')
plt.title('Linear Regression')
plt.ylabel('price')
plt.xlabel('grade')
plt.plot(x,model.predict(x), color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Split the dataset, Train test aned Linear regression for the feature:sqft_above
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x=data['sqft_above'].values[:,np.newaxis]
y=data['price'].values
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=30)

model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 78699518923.83076
# R squared 0.37214366379761354

# %%
# Plot the linear regression. 'sqft_above'

plt.scatter(x,y,color='r')
plt.title('Linear Regression')
plt.ylabel('price')
plt.xlabel('sqft_above')
plt.plot(x,model.predict(x), color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Split the dataset, Train test aned Linear regression for the feature:sqft_living15
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x=data['sqft_living15'].values[:,np.newaxis]
y=data['price'].values
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=30)

model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# MSE 83391358881.95305
# R squared 0.3347126669321091

# %%
# Plot the linear regression. 'sqft_living15'

plt.scatter(x,y,color='r')
plt.title('Linear Regression')
plt.ylabel('price')
plt.xlabel('sqft_living15')
plt.plot(x,model.predict(x), color='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# None of these items gives us a reliable model:
# The R squad is between 0.27 and 0.46.

# %% [markdown]
# Exercice 7) Apply multi-linear regression and compare it to the linear model.

# %%
x=data[['bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_living15']]
y=data['price'].values
x_train, x_test,y_train, y_test = train_test_split(x, y,test_size=0.20, random_state= 30)

#4. Apply Linear regression to your training set. 
model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)

print("a=",model.coef_)
print("b=",model.intercept_)



from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


print("MSE", mean_squared_error(y_test,predicted))
print("R squared",metrics.r2_score(y_test,predicted))
# Out:
# a= [-3.99292592e+04 -2.43180496e+04  2.76522587e+02  1.00869178e+05
#  -8.75368893e+01  2.72261830e+01]
# b= -518421.4744972241
# MSE 55898223040.49711
# R squared 0.5540499611897499

# %% [markdown]
# #Thanks to the multilinear regression which takes into account the impact of all these items at the same time. we have succeeded in creating a more efficient model than all the individual regression models that we have designed.
# we have reached a R squad of 0.55

# %% [markdown]
# Exercice8 Apply Polynomial regression and compare it to the linear and multilinear regression.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression



x=data[['bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_living15']]
y=data['price'].values
x_train, x_test,y_train, y_test = train_test_split(x, y,test_size=0.35, random_state= 30)

lg=LinearRegression()
poly=PolynomialFeatures(degree=2)


#Transformation de l'input à utiliser pour l'entreianement du model
x_train_fit = poly.fit_transform(x_train)

# Entrainement du model
lg.fit(x_train_fit, y_train)

#Transformation de l'input à utiliser pour la prdiction.
x_test_fit= poly.fit_transform(x_test)

# Prediction du model.
Predicted = lg.predict(x_test_fit)

# evaluation du model
print("MSE", mean_squared_error(y_test,Predicted))
print("R squared",metrics.r2_score(y_test,Predicted))

# %% [markdown]
# #Polynomial regression in degree 2 presents a better model than that linear and multilinear regression with an R squad

# %%
# Let's try a degree=3

x=data[['bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_living15']]
y=data['price'].values
x_train, x_test,y_train, y_test = train_test_split(x, y,test_size=0.35, random_state= 30)

lg=LinearRegression()
poly=PolynomialFeatures(degree=3)


#Transformation de l'input à utiliser pour l'entreianement du model
x_train_fit = poly.fit_transform(x_train)

# Entrainement du model
lg.fit(x_train_fit, y_train)

#Transformation de l'input à utiliser pour la prdiction.
x_test_fit= poly.fit_transform(x_test)

# Prediction du model.
Predicted = lg.predict(x_test_fit)

# evaluation du model
print("MSE", mean_squared_error(y_test,Predicted))
print("R squared",metrics.r2_score(y_test,Predicted))

# %% [markdown]
# #The model is slightly better

# %%
# (degree=4)

x=data[['bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_living15']]
y=data['price'].values
x_train, x_test,y_train, y_test = train_test_split(x, y,test_size=0.35, random_state= 30)

lg=LinearRegression()
poly=PolynomialFeatures(degree=4)


#Transformation de l'input à utiliser pour l'entreianement du model
x_train_fit = poly.fit_transform(x_train)

# Entrainement du model
lg.fit(x_train_fit, y_train)

#Transformation de l'input à utiliser pour la prdiction.
x_test_fit= poly.fit_transform(x_test)

# Prediction du model.
Predicted = lg.predict(x_test_fit)

# evaluation du model
print("MSE", mean_squared_error(y_test,Predicted))
print("R squared",metrics.r2_score(y_test,Predicted))

# %% [markdown]
# # The model is completely ineffective

# %%
#Filamentally we find that multi plynomial regression at degree 3 as is which provides us with the most efficient model.
